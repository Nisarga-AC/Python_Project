# %% [markdown]
# # Exploring Heart Attack Risk Factors: A Deep Dive into the Heart Data

# %% [markdown]
# <div style="text-align:center;">
#     <img src="https://media.tenor.com/eHzSzBI1QTYAAAAC/kamen-rider-revice-kamen-rider-revi.gif" alt="Centered Image">
# </div>

# %%
#Importing the libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
heart_df = pd.read_excel('/Users/harshams/Desktop/CIS5357_Assignments/Project/My_Project/heart_dataset.xlsx',sheet_name ='heart_dataset')

# %%
heart_df
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       SOH9843   22    Male          398         174/93          82
# 1       CQM6221   69    Male          250          95/78          75
# 2       GBX5187   75  Female          234         149/73          41
# 3       HZU0037   22  Female          345         179/82          72
# 4       SIO9750   77    Male          172         122/97          76
# ...         ...  ...     ...          ...            ...         ...
# 8758    EBZ6044   59    Male          240        141/104         109
# 8759    QNV8525   66    Male          355        170/104          56
# 8760    ZCI9519   21  Female          336        150/104          56
# 8761    LVA4734   28    Male          207        166/103          72
# 8762    EPE6801   36    Male          178         119/67          60
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0            1               1        1        0  ...
# ...

# %%
heart_df.shape
# Out:
# (8763, 26)

# %%
print("The number of rows in dataset is",heart_df.shape[0])
print("the number of columns in the dataset is",heart_df.shape[1])
# Out:
# The number of rows in dataset is 8763
# the number of columns in the dataset is 26

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
#checking for null values
heart_df[(heart_df.isnull().sum(axis=1)==1)]
# Out:
# Empty DataFrame
# Columns: [Patient ID, Age, Sex, Cholesterol, Blood Pressure, Heart Rate, Diabetes, Family History, Smoking, Obesity, Alcohol Consumption, Exercise Hours Per Week, Diet_CD, Previous Heart Problems, Medication Use, Stress Level, Sedentary Hours Per Day, Income, BMI, Triglycerides, Physical Activity Days Per Week, Sleep Hours Per Day, Country_CD, Continent_CD, Hemisphere_CD, Heart Attack Risk]
# Index: []
#
# [0 rows x 26 columns]

# %%
# checking for duplicates
heart_df[heart_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Patient ID, Age, Sex, Cholesterol, Blood Pressure, Heart Rate, Diabetes, Family History, Smoking, Obesity, Alcohol Consumption, Exercise Hours Per Week, Diet_CD, Previous Heart Problems, Medication Use, Stress Level, Sedentary Hours Per Day, Income, BMI, Triglycerides, Physical Activity Days Per Week, Sleep Hours Per Day, Country_CD, Continent_CD, Hemisphere_CD, Heart Attack Risk]
# Index: []
#
# [0 rows x 26 columns]

# %%
import numpy as np

def find_outliers_tukey ( x):
    q1 = np . percentile (x , 25)
    q3 = np . percentile (x , 75)
    iqr = q3 - q1
    floor = q1 - 1.5* iqr
    ceiling = q3 + 1.5* iqr
    outlier_indices = list (x. index [( x < floor ) |( x > ceiling ) ])
    outlier_values = list (x[ outlier_indices ])

    return outlier_indices , outlier_values

# %%
tukey_indices , tukey_values = find_outliers_tukey (heart_df['Heart Attack Risk'])

# %%
tukey_indices
# Out:
# []

# %%
tukey_values
# Out:
# []

# %%
heart_df.describe(include ="all")
# Out:
#        Patient ID          Age   Sex  Cholesterol Blood Pressure   Heart Rate  \
# count        8763  8763.000000  8763  8763.000000           8763  8763.000000
# unique       8763          NaN     2          NaN           3915          NaN
# top       SOH9843          NaN  Male          NaN         101/93          NaN
# freq            1          NaN  6111          NaN              8          NaN
# mean          NaN    53.707977   NaN   259.877211            NaN    75.021682
# std           NaN    21.249509   NaN    80.863276            NaN    20.550948
# min           NaN    18.000000   NaN   120.000000            NaN    40.000000
# 25%           NaN    35.000000   NaN   192.000000            NaN    57.000000
# 50%           NaN    54.000000   NaN   259.000000            NaN    75.000000
# 75%           NaN    72.000000   NaN   330.000000            NaN    93.000000
# max           NaN    90.000000   NaN   400.000000            NaN   110.000000
#
# ...

# %%
heart_df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    SOH9843   22    Male          398         174/93          82         1
# 1    CQM6221   69    Male          250          95/78          75         1
# 2    GBX5187   75  Female          234         149/73          41         0
# 3    HZU0037   22  Female          345         179/82          72         0
# 4    SIO9750   77    Male          172         122/97          76         0
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               1        1        0  ...                 5.204852  259754
# 1               1        1        1  ...                 9.954965   57106
# 2               1        1        1  ...                 0.693204   43227
# 3               1        0        1  ...                 2.647330  147795
# 4               1        1        1  ...                11.159123   32763
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
heart_df.tail()
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 8758    EBZ6044   59    Male          240        141/104         109
# 8759    QNV8525   66    Male          355        170/104          56
# 8760    ZCI9519   21  Female          336        150/104          56
# 8761    LVA4734   28    Male          207        166/103          72
# 8762    EPE6801   36    Male          178         119/67          60
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 8758         0               0        1        1  ...
# 8759         1               0        1        1  ...
# 8760         1               1        0        0  ...
# 8761         0               1        1        1  ...
# 8762         1               0        1        0  ...
#
#       Sedentary Hours Per Day  Income        BMI  Triglycerides  \
# 8758                10.202352  176544  28.268582            473
# 8759                 9.164325   74044  29.342095            732
# ...

# %%
heart_df.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet_CD',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country_CD',
#        'Continent_CD', 'Hemisphere_CD', 'Heart Attack Risk'],
#       dtype='object')

# %%
heart_df['Heart Attack Risk'].value_counts()
# Out:
# Heart Attack Risk
# 0    5624
# 1    3139
# Name: count, dtype: int64

# %%
# Heart Attack Risk Distribution
sns.countplot(data=heart_df, x='Heart Attack Risk')
plt.xticks([0,1],['No_Heart_attack','Heart_Attack'])
plt.title('Heart Attack Risk Distribution')
plt.show()

# %% [markdown]
# ### Findings :
#
# From the graph,we can notice that there are **5624** people with no Heart attack risk and **3139** people have heart attack risk.

# %% [markdown]
# ## Demographics
#
# ### 1. Gender :

# %%
heart_df['Sex'].value_counts()
# Out:
# Sex
# Male      6111
# Female    2652
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
gender_counts = heart_df['Sex'].value_counts()
axes[0].pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
axes[0].set_title('Gender Distribution')

sns.countplot(x='Sex', hue='Heart Attack Risk', data=heart_df, ax=axes[1])
axes[1].legend(['No Heart Disease', 'Heart Disease'])
axes[1].set_title('Heart Disease Risk by Gender')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings :
#
# * The pie chart shows the gender distribution and bar chart shows the heart disease risk by gender.
#
# * The total number of men is 6111, and the total number of women is 2652.
#
# * **Gender distribution:**
#    * Men: 69.7%
#    * Women: 30.3%
#
# * **Heart disease risk by gender:**
#    * Men: 35.92%
#    * Women: 35.59%
#
#
# * The percentage of men with a heart attack risk is slightly higher than the percentage of women with a heart attack risk. However, the overall risk of heart disease is similar for both men and women.

# %% [markdown]
# ### 2. Age :

# %%
sns.histplot(x='Age',data =heart_df ,kde = True)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 6)) 
sns.boxplot(data=heart_df, x='Heart Attack Risk', y='Age')
plt.title('Age Distribution by Heart Attack Risk')
plt.xlabel('Heart Attack Risk')
plt.xticks([0,1],['No Heart Attack','Heart Attack'])
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ### Findings :
#
# * The boxplot shows the age distribution by heart attack risk, with blue representing people with no heart attack risk and orange representing people with a risk of heart attack.
#
# * The median age of both groups is 54 years old, but the orange box plot (representing people with heart attack risk) is shifted to the right, meaning that people with heart attack risk are more likely to be older.
#
# * The orange box plot is also wider than the blue box plot, meaning that there is more variability in the age of people with heart attack risk. This suggests that heart attack risk can occur at any age, even in young people, but it is more likely to occur in older people.

# %% [markdown]
# ## Lifestyle Factors:
#
# ### 1. Smoking and Alcohol consumption :

# %%
heart_df['Smoking'].value_counts()
# Out:
# Smoking
# 1    7859
# 0     904
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))


smokers_counts = heart_df['Smoking'].value_counts()
axes[0, 0].pie(smokers_counts, labels=['Smoker', 'Non-Smoker'], autopct='%1.1f%%')
axes[0, 0].set_title('Smoker/Non-Smoker Distribution')


alcoholic_counts = heart_df['Alcohol Consumption'].value_counts()
axes[0, 1].pie(alcoholic_counts, labels=['Alcoholic', 'Non-alcoholic'], autopct='%1.1f%%')
axes[0, 1].set_title('Alcoholic/Non-alcoholic Distribution')


sns.countplot(x='Smoking', hue='Heart Attack Risk', data=heart_df, ax=axes[1, 0])
axes[1, 0].set_title("Heart Attack Risk compared with Smoking")
axes[1, 0].set_xticks([0, 1])
axes[1, 0].set_xticklabels(['Non-Smokers', 'Smokers'])
axes[1, 0].legend(['No Heart Attack', 'Heart Attack'])


sns.countplot(x='Alcohol Consumption', hue='Heart Attack Risk', data=heart_df, ax=axes[1, 1])
axes[1, 1].set_title("Heart Attack Risk compared with Alcohol Consumption")
axes[1, 1].set_xticks([0, 1])
axes[1, 1].set_xticklabels(['Non-alcoholic', 'Alcoholic'])
axes[1, 1].legend(['No Heart Attack', 'Heart Attack'])


plt.tight_layout()
plt.show()

# %%
# Data for smokers and non-smokers
smoke_with_heart_attack_risk = 2810
smoke_without_heart_attack_risk = 5049
total_smoke = smoke_with_heart_attack_risk + smoke_without_heart_attack_risk

non_smoke_with_heart_attack_risk = 329
non_smoke_without_heart_attack_risk = 575
total_non_smoke = non_smoke_with_heart_attack_risk + non_smoke_without_heart_attack_risk

# Data for drinkers and non-drinkers
alcholic_with_heart_attack_risk = 1849
alcholic_without_heart_attack_risk = 3392
total_alcholic = alcholic_with_heart_attack_risk + alcholic_without_heart_attack_risk

non_alcholic_with_heart_attack_risk = 1290
non_alcholic_without_heart_attack_risk = 2232
total_non_alcholic = non_alcholic_with_heart_attack_risk + non_alcholic_without_heart_attack_risk

# Calculate percentages
smoke_heart_attack_risk_percentage = (smoke_with_heart_attack_risk / total_smoke) * 100
non_smoke_heart_attack_risk_percentage = (non_smoke_with_heart_attack_risk / total_non_smoke) * 100

alcholic_heart_attack_risk_percentage = (alcholic_with_heart_attack_risk / total_alcholic) * 100
non_alcholic_heart_attack_risk_percentage = (non_alcholic_with_heart_attack_risk / total_non_alcholic) * 100

# Data for pie charts
smoker_data = [smoke_heart_attack_risk_percentage, 100 - smoke_heart_attack_risk_percentage]
non_smoker_data = [non_smoke_heart_attack_risk_percentage, 100 - non_smoke_heart_attack_risk_percentage]

alcholic_data = [alcholic_heart_attack_risk_percentage, 100 - alcholic_heart_attack_risk_percentage]
non_alcholic_data = [non_alcholic_heart_attack_risk_percentage, 100 - non_alcholic_heart_attack_risk_percentage]

# Plotting side-by-side pie charts for smokers and non-smokers
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Smokers Pie Chart
axes[0].pie(smoker_data, labels=['Heart Attack Risk', 'No Heart Attack Risk'], autopct='%1.1f%%', startangle=90)
axes[0].set_title('Smokers')

# Non-Smokers Pie Chart
axes[1].pie(non_smoker_data, labels=['Heart Attack Risk', 'No Heart Attack Risk'], autopct='%1.1f%%', startangle=90)
axes[1].set_title('Non-Smokers')

plt.tight_layout()
plt.show()

# Plotting side-by-side pie charts for drinkers and non-drinkers
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Drinkers Pie Chart
axes[0].pie(alcholic_data, labels=['Heart Attack Risk', 'No Heart Attack Risk'], autopct='%1.1f%%', startangle=90)
axes[0].set_title('Alcholic')

# Non-Drinkers Pie Chart
axes[1].pie(non_alcholic_data, labels=['Heart Attack Risk', 'No Heart Attack Risk'], autopct='%1.1f%%', startangle=90)
axes[1].set_title('Non-Alcholic')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings :
#
# #### Heart Attack Risk compared with Smoking :
# * In the provide data set, 89.7% people are Smokers and 10.3% people are non-Smokers.
#
# * The bar chart shows the risk of heart attack in smokers and non-smokers. The x-axis shows the smoking status (smoker or non-smoker), and the y-axis shows the risk of heart attack.
#
# * Heart attack risk percentage of Smokers is 35.8%
#
# * Heart attack risk percentage of Non-Smokers is 36.4%
#
# * The heart attack risk percentage is slightly higher for non-smokers than for smokers. However, the difference is relatively small. It is important to note that these are just averages, and the individual risk of heart attack can vary depending on a number of factors, including age, family history, high blood pressure, high cholesterol, diabetes and other medical conditions.
#
#
# #### Heart Attack Risk compared with Alcohol Consumption :
# * In the provide data set, 59.8% people are Alcoholic and 40.2% people are non-Alcoholic
#
# * The bar chart shows the risk of heart attack in alcoholics and non-alcoholics. The x-axis shows the alcohol consumption status (alcoholic or non-alcoholic), and the y-axis shows the risk of heart attack.
#
# * Heart attack risk percentage of Alcoholic is 35.3%
#
# * Heart attack risk percentage of Non-Alcoholic is 36.6%
#
# * The heart attack risk percentage is slightly higher for non-alcoholics than for alcoholics. However, the difference is relatively small. It is important to note that these are just averages, and the individual risk of heart attack can vary depending on a number of factors, including age, family history, high blood pressure, high cholesterol, diabetes and other medical conditions.

# %% [markdown]
# ### 2. Sleep, exercise, and physical activity :

# %%
sleep_hours = heart_df.groupby('Heart Attack Risk')['Sleep Hours Per Day'].agg(['sum', 'mean','count'])

sleep_hours
# Out:
#                      sum      mean  count
# Heart Attack Risk
# 0                  39655  7.051031   5624
# 1                  21892  6.974196   3139

# %%
Excercise_hours = heart_df.groupby('Heart Attack Risk')['Exercise Hours Per Week'].agg(['sum', 'mean','count'])

Excercise_hours
# Out:
#                             sum       mean  count
# Heart Attack Risk
# 0                  56049.805875   9.966182   5624
# 1                  31705.361796  10.100466   3139

# %%
Physical_Activity = heart_df.groupby('Heart Attack Risk')['Physical Activity Days Per Week'].agg(['sum', 'mean','count'])

Physical_Activity
# Out:
#                      sum      mean  count
# Heart Attack Risk
# 0                  19674  3.498222   5624
# 1                  10906  3.474355   3139

# %%
heart_df.groupby('Heart Attack Risk')[['Sleep Hours Per Day','Exercise Hours Per Week','Physical Activity Days Per Week']].sum().plot(kind='bar')
plt.ylabel("sum")
plt.xticks([0,1],['No Heart attack Risk','Heart attack Risk'],rotation= 0)
plt.title("Sleep, Excercise and Physical Activity compared with Heart Attack Risk ")
plt.show()

# %% [markdown]
# ### Findings :
#
# #### Sleep, Excercise and Physical Activity compared with Heart Attack Risk :
#
# * The graph shows the relationship between sleep hours per day, exercise hours per week, and physical activity days per week with heart attack risk.
#
# * The y-axis shows the sum of sleep hours per day and exercise hours per week, and the physical activity days per week and x-axis shows the Heart Attack Risk
#
# * The graph shows that people who have a higher sum of sleep hours per day and exercise hours per week have a lower risk of heart attack. This is because sleep and exercise are both important for maintaining good cardiovascular health.
#
# * The graph also shows that people who are more physically active have a lower risk of heart attack. This is because physical activity helps to reduce inflammation, stress, and weight gain, all of which are risk factors for heart attack.
#
# * Overall, the graph shows that sleep, exercise, and physical activity are all important factors that can help to reduce the risk of heart attack.

# %% [markdown]
# ### 3. Diet :

# %%
df_diet = pd.read_excel('/Users/harshams/Desktop/CIS5357_Assignments/Project/My_Project/heart_dataset.xlsx',sheet_name ='diet_code')

# %%
df_diet
# Out:
#    Diet_CD       Diet
# 0        1    Average
# 1        2  Unhealthy
# 2        3    Healthy

# %%
merged_df = pd.merge(df_diet,heart_df[['Diet_CD','Heart Attack Risk']],how = 'inner',on = 'Diet_CD')

# %%
merged_df
# Out:
#       Diet_CD     Diet  Heart Attack Risk
# 0           1  Average                  1
# 1           1  Average                  0
# 2           1  Average                  1
# 3           1  Average                  1
# 4           1  Average                  1
# ...       ...      ...                ...
# 8758        3  Healthy                  1
# 8759        3  Healthy                  0
# 8760        3  Healthy                  1
# 8761        3  Healthy                  0
# 8762        3  Healthy                  1
#
# [8763 rows x 3 columns]

# %%
merged_df.groupby(['Diet_CD','Diet'])['Heart Attack Risk'].value_counts()
# Out:
# Diet_CD  Diet       Heart Attack Risk
# 1        Average    0                    1886
#                     1                    1026
# 2        Unhealthy  0                    1857
#                     1                    1034
# 3        Healthy    0                    1881
#                     1                    1079
# Name: count, dtype: int64

# %%
fig , axes = plt.subplots(1,2,figsize= (12,5))

diet_counts = merged_df['Diet'].value_counts()
axes[0].pie(diet_counts,labels =diet_counts.index, autopct='%1.1f%%')
axes[0].set_title("Distribution of Diet")


ax= sns.countplot(x='Diet',hue='Heart Attack Risk',data=merged_df, ax=axes[1])
ax.legend(title='Heart Attack Risk', labels=['No_Heart_risk', 'Heart_Risk'], bbox_to_anchor=(1.05, 1), loc='upper left')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
axes[1].set_title("Diet compared with Heart Attack Risk")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings:
#
# 1. The graph shows the number of people with and without a heart attack risk, according to their diet. The blue bars represent people with no heart attack risk, and the orange bars represent people with a heart attack risk. The height of the bars represents the number of people.
#
#     The key takeaways from the graph are:
#
#     * **Average diet:** There are 1026 people with a heart attack risk and 1886 people with no heart attack risk.
#     * **Unhealthy diet:** There are 1034 people with a heart attack risk and 1857 people with no heart attack risk.
#     * **Healthy diet:** There are 1079 people with a heart attack risk and 1881 people with no heart attack risk.
#
#  -   **People who eat a healthy diet have the highest number of heart attack risks:** This may seem counterintuitive, but it's important to remember that correlation does not equal causation. There may be other factors that explain this relationship, such as age, genetics, or exercise habits.
#
# -    **People who eat an unhealthy diet have the second-highest number of heart attack risks:** This is more in line with what we expect to see. However, it's important to note that the difference between the unhealthy and healthy diet groups is relatively small.
#
# -    **People who eat an average diet have the lowest number of heart attack risks:** This suggests that there may be some benefit to eating a healthy diet, but it's not a guarantee that you will avoid a heart attack.
#
# 2. Even though the "Healthy" group has the most people, the percentage of people with heart attack risk is also the highest (36.45%) compared to the "Average" (35.23%) and "Unhealthy" (35.77%) groups. Therefore, while the larger population size in the "Healthy" group contributes to the higher absolute number of heart attacks, it is not the only explanation.
#
#     There might be other factors at play, such as:
#
#     * **Age distribution:** The "Healthy" group might have a higher proportion of older adults, who are generally more at risk of heart attacks.
#     * **Specific dietary components:** The "Healthy" diet might contain certain ingredients or lack others that could contribute to heart attack risk, despite being overall healthier.
#     * **Other lifestyle factors:** Smoking, exercise habits, and genetics could also play a role, and their distribution might differ across the groups.
#
#
#     Overall, the graph suggests that diet may play a role in heart attack risk, but it's not the only factor. More research is needed to determine the exact relationship between diet and heart health.
#
#     Here are some additional questions that the graph raises:
#
#     * What are the specific diets that are considered "healthy," "unhealthy," and "average"?
#     * What other factors, besides diet, could explain the relationship between diet and heart attack risk?

# %% [markdown]
# ## Medical factors
#
# ### 1. Cholesterol :

# %%
# Create separate DataFrames for patients with and without heart attack risk
heart_attack_patients = heart_df[heart_df['Heart Attack Risk'] == 1]
no_heart_attack_patients = heart_df[heart_df['Heart Attack Risk'] == 0]

# Create density plots to compare cholesterol levels
plt.figure(figsize=(10, 6))
sns.kdeplot(heart_attack_patients['Cholesterol'], label='Heart Attack Patients')
sns.kdeplot(no_heart_attack_patients['Cholesterol'], label='No Heart Attack')
plt.xlabel('Cholesterol Levels')
plt.ylabel('Density')
plt.title('Cholesterol Levels by Heart Attack Risk')
plt.legend()
plt.show()

# Create box plots to compare cholesterol levels
plt.figure(figsize=(10, 6))
sns.boxplot(x='Heart Attack Risk', y='Cholesterol', data=heart_df)
plt.xlabel('Heart Attack Risk')
plt.ylabel('Cholesterol Levels')
plt.title('Cholesterol Levels by Heart Attack Risk')
plt.xticks([0, 1], ['No Heart Attack', 'Heart Attack Patients'])
plt.show()

# %% [markdown]
# ### Findings :
#
# #### Density plots:
#
# * The graph shows the relationship between cholesterol levels and heart attack risk. The x-axis shows cholesterol levels and the y-axis shows the density of heart attack risk. The line on the graph shows how the risk of heart attack increases as cholesterol levels increase.
#
# * The graph shows that people with higher cholesterol levels have a higher risk of heart attack. For example, people with cholesterol levels of 200 mg/dL or higher have a two-fold higher risk of heart attack than people with cholesterol levels below 160 mg/dL.
#
# * The graph also shows that the risk of heart attack increases sharply as cholesterol levels increase above 200 mg/dL. This means that even a small increase in cholesterol levels above 200 mg/dL can significantly increase the risk of heart attack.
#
# ####  Boxplot :
#
# * The boxplot represents the cholesterol levels by heart attack risk. The blue boxplot represents people with no heart attack risk and the orange boxplot represents people with heart attack risk.
#
# * The median cholesterol level is higher in people with heart attack risk (orange boxplot) than in people with no heart attack risk (blue boxplot). This means that people with heart attack risk are more likely to have high cholesterol.
#
# * The orange boxplot is also wider than the blue boxplot, meaning that there is more variability in cholesterol levels in people with heart attack risk. This suggests that some people with heart attack risk may have very high cholesterol levels, while others may have cholesterol levels that are only slightly elevated.
#
# * Overall, the boxplot shows that people with heart attack risk are more likely to have high cholesterol than people with no heart attack risk. However, it is important to note that there is some variability in cholesterol levels in both groups, and some people with heart attack risk may have cholesterol levels that are within the normal range.

# %% [markdown]
# ### 2. Blood pressure :

# %%
split_blood_pressure = heart_df['Blood Pressure'].str.split('/', expand=True)
heart_df['Systolic BP'] = split_blood_pressure[0].astype(int)
heart_df['Diastolic BP'] = split_blood_pressure[1].astype(int)

# Create a box plot to compare systolic blood pressure
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sex', y='Systolic BP', hue='Heart Attack Risk', data=heart_df, width=0.6)
plt.xlabel('Sex')
plt.ylabel('Systolic Blood Pressure')
plt.title('Systolic Blood Pressure by Sex and Heart Attack Risk')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# Create a box plot to compare diastolic blood pressure
plt.figure(figsize=(10, 6))
sns.boxplot(x='Sex', y='Diastolic BP', hue='Heart Attack Risk', data=heart_df, width=0.6)
plt.xlabel('Sex')
plt.ylabel('Diastolic Blood Pressure')
plt.title('Diastolic Blood Pressure by Sex and Heart Attack Risk')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# %% [markdown]
# ### Findings :
#
# #### Systolic Blood Pressure by Sex and Heart Attack Risk :
#
# The box plot shows the distribution of systolic blood pressure by sex and heart attack risk. The x-axis shows the sex (male or female) , and the y-axis shows the systolic blood pressure with respect to heart attack risk (no risk or at risk).
#
# -  **Comparison of males and females** : The median Systolic Blood Pressure is higher in males than in females for both heart attack risk groups. This means that males have a higher SBP on average than females.
#
# -  **Comparison of heart attack risk groups** : The median Systolic Blood Pressure is higher in people with heart attack risk than in people with no heart attack risk for both males and females. This means that people with heart attack risk have a higher SBP on average than people with no heart attack risk.
#
# #### Diastolic Blood Pressure by Sex and Heart Attack Risk :
#
# The box plot shows the distribution of Diastolic blood pressure by sex and heart attack risk. The x-axis shows the sex (male or female) , and the y-axis shows the Diastolic blood pressure with respect to heart attack risk (no risk or at risk).
#
# - **Comparison of males and females** : The median Diastolic blood pressure is higher in males than in females for both heart attack risk groups. This means that males have a higher DBP on average than females.
#
# - **Comparison of heart attack risk groups** : The median Diastolic blood pressure  is higher in people with heart attack risk than in people with no heart attack risk for both males and females. This means that people with heart attack risk have a higher DBP on average than people with no heart attack risk.

# %% [markdown]
# ### 3. Heart rate :

# %%
# Create histograms to visualize heart rate distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=heart_df, x='Heart Rate', hue='Heart Attack Risk', element='step', common_norm=False)
plt.xlabel('Heart Rate')
plt.ylabel('Frequency')
plt.title('Heart Rate Distribution by Heart Attack Risk')
plt.legend(title='Heart Attack Risk', labels=['No Heart Attack', 'Heart Attack'],loc= 'lower right')
plt.show()

# %% [markdown]
# ### Findings :
#
# #### Heart Rate Distribution by Heart Attack Risk:
#
# * The graph shows the heart rate distribution by heart attack risk. The x-axis shows heart rate in beats per minute, and the y-axis shows frequency. The graph is divided into two sections: no heart attack and heart attack patients.
#
# * The graph also shows that the distribution of heart rate is wider for people with heart attack than for people with no heart attack. This means that there is a greater range of heart rates among people with heart attack.
#
# * There is a small overlap in the heart rate distribution between people with no heart attack and people with heart attack. This means that it is not possible to predict with 100% accuracy whether someone has a heart attack based on their heart rate alone.
#
# * Overall, the graph suggests that there is a relationship between heart rate and heart attack risk. People with heart attack tend to have higher heart rates than people with no heart attack. However, it is important to note that heart rate is just one factor that can contribute to heart attack risk.

# %% [markdown]
# ### 4. Diabetes, family history, and previous heart problems :

# %%
# Calculate the proportions of diabetes, family history, and previous heart problems by Heart Attack Risk
diabetes_proportions = heart_df.groupby('Heart Attack Risk')['Diabetes'].value_counts(normalize=True)[:, 1]
family_history_proportions = heart_df.groupby('Heart Attack Risk')['Family History'].value_counts(normalize=True)[:, 1]
previous_heart_problems_proportions = heart_df.groupby('Heart Attack Risk')['Previous Heart Problems'].value_counts(normalize=True)[:, 1]

# Create a DataFrame for plotting
data = pd.DataFrame({
    'Diabetes': diabetes_proportions,
    'Family History': family_history_proportions,
    'Previous Heart Problems': previous_heart_problems_proportions
})

# Create a stacked bar chart
data.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Proportion of Patients with Diabetes, Family History, and Previous Heart Problems by Heart Attack Risk')
plt.xlabel('Heart Attack Risk')
plt.ylabel('Proportion')
plt.xticks([0, 1], ['No Heart Attack', 'Heart Attack'], rotation=0)
plt.legend(title='Medical History',bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# ### Findings:
#
# #### Proportion of Patients with Diabetes, Family History, and Previous Heart Problems by Heart Attack Risk :
#
# The provided graph illustrates the proportion of patients with diabetes, family history, and previous heart problems based on their risk of experiencing a heart attack. It demonstrates that individuals with diabetes, family history, or previous heart problems have a significantly higher likelihood of having a heart attack compared to those without these risk factors.
#
# **Key takeaways from the graph:**
#
# 1. **Diabetes:** Patients with diabetes have the highest proportion of experiencing a heart attack among the three groups. This underscores the strong association between diabetes and cardiovascular disease, particularly heart attacks.
#
# 2. **Family history:** Individuals with a family history of heart attacks, even without any personal history of heart disease, have a higher risk of developing heart problems. This highlights the hereditary component of heart disease and the importance of early screening and preventive measures.
#
# 3. **Previous heart problems:** Individuals with a history of heart attacks have the highest risk of experiencing another heart attack. This emphasizes the importance of ongoing care and lifestyle modifications for individuals who have previously faced heart issues.
#
# In conclusion, the graph clearly demonstrates the increased risk of heart attacks for individuals with diabetes, family history, or previous heart problems. These factors serve as crucial indicators for assessing cardiovascular risk and implementing preventive measures to minimize the risk of heart attacks.

# %% [markdown]
# ### 5. Triglycerides :

# %%
# Density plot for Triglycerides
# Create separate DataFrames for patients with and without heart attack risk
heart_attack_patients = heart_df[heart_df['Heart Attack Risk'] == 1]
no_heart_attack_patients = heart_df[heart_df['Heart Attack Risk'] == 0]

# Create density plots to compare cholesterol levels
sns.kdeplot(heart_attack_patients['Triglycerides'], label='Heart Attack Risk')
sns.kdeplot(no_heart_attack_patients['Triglycerides'], label='No Heart Attack Risk')
plt.xlabel('Triglycerides Levels')
plt.ylabel('Density')
plt.title('Distribution of Triglyceride Levels by Heart Attack Risk')
plt.legend()
plt.show()

# %% [markdown]
# ### Findings:
#
# #### Distribution of Triglyceride Levels by Heart Attack Risk :
#
# * The graph shows the distribution of triglyceride levels by heart attack risk. The x-axis shows triglyceride levels in milligrams per deciliter (mg/dL), and the y-axis shows the density of people with each triglyceride level. The density is represented by the height of the bars on the graph.
#
# * The graph shows that the higher the triglyceride levels, the higher the heart attack risk. The bar for people with no heart attack risk is tallest at the lowest triglyceride levels, and the bars for people with higher heart attack risk get taller as the triglyceride levels increase.
#
# * The graph also shows that people who have triglyceride levels below 200 mg/dL are considered as healthy triglyceride level. However, a group of people have triglyceride levels above 400 mg/dL. This is considered to be very high triglyceride levels, and it puts people at an increased risk of heart attack.
#
# * The graph also shows that there are some people with high triglyceride levels who do not have a heart attack, and some people with low triglyceride levels who do have a heart attack. This is because there are other factors that can also contribute to heart attack risk, such as cholesterol levels, blood pressure, and diabetes.
#
# * Overall, the graph shows that there is a strong relationship between triglyceride levels and heart attack risk. People with higher triglyceride levels have a higher risk of heart attack. It is important to keep triglyceride levels in a healthy range to reduce the risk of heart attack.

# %% [markdown]
# ## Geographic factors
#
# ### 1. Countries :

# %%
df_country = pd.read_excel('/Users/harshams/Desktop/CIS5357_Assignments/Project/My_Project/heart_dataset.xlsx',sheet_name ='geo_code',usecols=['Country_CD','Country'])

# %%
df_country
# Out:
#     Country_CD         Country
# 0            1       Argentina
# 1            2       Australia
# 2            3          Brazil
# 3            4          Canada
# 4            5           China
# 5            6        Colombia
# 6            7          France
# 7            8         Germany
# 8            9           India
# 9           10           Italy
# 10          11           Japan
# 11          12     New Zealand
# 12          13         Nigeria
# 13          14    South Africa
# 14          15     South Korea
# 15          16           Spain
# 16          17        Thailand
# 17          18  United Kingdom
# 18          19   United States
# 19          20         Vietnam

# %%
geo_country_df = pd.merge(df_country,heart_df[['Country_CD','Heart Attack Risk']],how = 'inner',on ='Country_CD')

# %%
geo_country_df
# Out:
#       Country_CD    Country  Heart Attack Risk
# 0              1  Argentina                  0
# 1              1  Argentina                  0
# 2              1  Argentina                  1
# 3              1  Argentina                  0
# 4              1  Argentina                  0
# ...          ...        ...                ...
# 8758          20    Vietnam                  0
# 8759          20    Vietnam                  0
# 8760          20    Vietnam                  0
# 8761          20    Vietnam                  1
# 8762          20    Vietnam                  0
#
# [8763 rows x 3 columns]

# %%
#Countries are sorted by No Heart Attack Risk
pd.crosstab(geo_country_df['Country'], geo_country_df['Heart Attack Risk']).sort_values(by = 0, ascending = False)
# Out:
# Heart Attack Risk    0    1
# Country
# Germany            305  172
# Brazil             299  163
# Argentina          297  174
# United Kingdom     297  160
# Italy              295  136
# France             289  157
# Japan              289  144
# New Zealand        284  151
# India              283  129
# Canada             282  158
# China              281  155
# Australia          281  168
# South Africa       281  144
# Spain              280  150
# Vietnam            277  148
# Nigeria            270  178
# Colombia           267  162
# Thailand           267  161
# United States      254  166
# South Korea        246  163

# %%
#Countries are sorted by Heart Attack Risk
pd.crosstab(geo_country_df['Country'], geo_country_df['Heart Attack Risk']).sort_values(by = 1, ascending = False)
# Out:
# Heart Attack Risk    0    1
# Country
# Nigeria            270  178
# Argentina          297  174
# Germany            305  172
# Australia          281  168
# United States      254  166
# Brazil             299  163
# South Korea        246  163
# Colombia           267  162
# Thailand           267  161
# United Kingdom     297  160
# Canada             282  158
# France             289  157
# China              281  155
# New Zealand        284  151
# Spain              280  150
# Vietnam            277  148
# South Africa       281  144
# Japan              289  144
# Italy              295  136
# India              283  129

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

#Countries are sorted by No Heart Attack Risk(0):
pd.crosstab(geo_country_df['Country'], geo_country_df['Heart Attack Risk']).sort_values(by = 0, ascending = False).plot(kind='bar', stacked=True,ax=axes[0])
axes[0].legend(['No Heart Attack','Heart Attack'],title = 'Heart Attack Risk', bbox_to_anchor = (1,1))
axes[0].set_title("Countries are sorted by No Heart Attack Risk")


#Countries are sorted by Heart Attack Risk(1):
pd.crosstab(geo_country_df['Country'], geo_country_df['Heart Attack Risk']).sort_values(by = 1, ascending = False).plot(kind='bar', stacked=True,ax=axes[1])
axes[1].legend(['No Heart Attack','Heart Attack'],title = 'Heart Attack Risk', bbox_to_anchor = (1,1))
axes[1].set_title("Countries are sorted by Heart Attack Risk")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings:
#
# #### Top5 Countries sorted by No Heart Attack Risk :
#
# * Germany
# * Brazil
# * Argentina
# * United Kingdom
# * Italy
#
# #### Top5 Countries sorted by Heart Attack Risk :
#
# * Nigeria
# * Argentina
# * Germany
# * Australia
# * United States

# %% [markdown]
# ### 2. Continent :

# %%
df_continent = pd.read_excel('/Users/harshams/Desktop/CIS5357_Assignments/Project/My_Project/heart_dataset.xlsx',sheet_name ='geo_code',usecols=['Continent_CD','Continent'])

# %%
df_continent.dropna()
# Out:
#    Continent_CD      Continent
# 0           1.0         Africa
# 1           2.0           Asia
# 2           3.0      Australia
# 3           4.0         Europe
# 4           5.0  North America
# 5           6.0  South America

# %%
geo_continent_df = pd.merge(df_continent,heart_df[['Continent_CD','Heart Attack Risk']],how = 'inner',on ='Continent_CD')

# %%
geo_continent_df['Continent_CD'] = geo_continent_df['Continent_CD'].astype('int64')

# %%
geo_continent_df
# Out:
#       Continent_CD      Continent  Heart Attack Risk
# 0                1         Africa                  1
# 1                1         Africa                  0
# 2                1         Africa                  1
# 3                1         Africa                  1
# 4                1         Africa                  1
# ...            ...            ...                ...
# 8758             6  South America                  0
# 8759             6  South America                  0
# 8760             6  South America                  0
# 8761             6  South America                  0
# 8762             6  South America                  0
#
# [8763 rows x 3 columns]

# %%
sns.countplot(x='Continent',hue = 'Heart Attack Risk',data = geo_continent_df )
plt.xticks(rotation = 45)
plt.legend(['No Heart Attack','Heart Attack'])
plt.show()

# %%
pd.crosstab(geo_continent_df['Continent'], geo_continent_df['Heart Attack Risk']).sort_values(by = 1, ascending = False)
# Out:
# Heart Attack Risk     0    1
# Continent
# Asia               1643  900
# Europe             1466  775
# South America       863  499
# North America       536  324
# Africa              551  322
# Australia           565  319

# %%
pd.crosstab(geo_continent_df['Continent'], geo_continent_df['Heart Attack Risk']).sort_values(by = 0, ascending = False)
# Out:
# Heart Attack Risk     0    1
# Continent
# Asia               1643  900
# Europe             1466  775
# South America       863  499
# Australia           565  319
# Africa              551  322
# North America       536  324

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

pd.crosstab(geo_continent_df['Continent'], geo_continent_df['Heart Attack Risk']).sort_values(by = 0, ascending = False).plot(kind='bar',stacked = True,ax=axes[0])
axes[0].set_title("Continents are sorted by No Heart Attack Risk")
axes[0].legend(['No Heart Attack','Heart Attack'])

pd.crosstab(geo_continent_df['Continent'], geo_continent_df['Heart Attack Risk']).sort_values(by = 1, ascending = False).plot(kind='bar',stacked = True,ax=axes[1])
axes[1].set_title("Continents are sorted by Heart Attack Risk")
axes[1].legend(['No Heart Attack','Heart Attack'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings:
#
# #### Continent sorted by No Heart Attack Risk :
#
# * Asia
# * Europe
# * South America
# * Australia
# * Africa
# * North America
#
# #### Continent sorted by Heart Attack Risk :
#
# * Asia
# * Europe
# * South America
# * North America
# * Africa
# * Australia

# %% [markdown]
# ### 3. Hemisphere :

# %%
df_Hemisphere = pd.read_excel('/Users/harshams/Desktop/CIS5357_Assignments/Project/My_Project/heart_dataset.xlsx',sheet_name ='geo_code',usecols=['Hemisphere_CD','Hemisphere'])

# %%
df_Hemisphere.dropna()
# Out:
#   Hemisphere_CD           Hemisphere
# 0             N  Northern Hemisphere
# 1             S  Southern Hemisphere

# %%
geo_Hemisphere_df = pd.merge(df_Hemisphere,heart_df[['Hemisphere_CD','Heart Attack Risk']],how = 'inner',on ='Hemisphere_CD')

# %%
geo_Hemisphere_df
# Out:
#      Hemisphere_CD           Hemisphere  Heart Attack Risk
# 0                N  Northern Hemisphere                  1
# 1                N  Northern Hemisphere                  0
# 2                N  Northern Hemisphere                  1
# 3                N  Northern Hemisphere                  1
# 4                N  Northern Hemisphere                  1
# ...            ...                  ...                ...
# 8758             S  Southern Hemisphere                  0
# 8759             S  Southern Hemisphere                  0
# 8760             S  Southern Hemisphere                  0
# 8761             S  Southern Hemisphere                  0
# 8762             S  Southern Hemisphere                  0
#
# [8763 rows x 3 columns]

# %%
sns.countplot(x='Hemisphere',hue = 'Heart Attack Risk',data = geo_Hemisphere_df )
plt.legend(['No Heart Attack','Heart Attack'],title = 'Heart Attack Risk')
plt.title(" Risk of Heart Attack by Hemisphere ")
plt.show()

# %% [markdown]
# ### Findings :
#
# #### Risk of Heart Attack by Hemisphere:
#
# * The bar graph shows the risk of heart attack in the northern hemisphere and the southern hemisphere. The number of people who have heart attack risk in the northern hemisphere is higher than the number of people who have the  heart attack risk in the southern hemisphere.
#
# * Similarly the number of people who have no heart attack risk in the northern hemisphere is higher than the number of people who have no heart attack risk in the southern hemisphere.

# %% [markdown]
# ## Correlation Heatmap with Heart Attack Risk

# %%
# Select only numeric columns for the correlation matrix
numeric_columns = heart_df.select_dtypes(include=['number'])

# Calculate the correlation matrix
corr_matrix = numeric_columns.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix[['Heart Attack Risk']], annot=True, cmap = 'plasma',linewidths=0.5)
plt.title('Correlation Heatmap with Heart Attack Risk')
plt.show()

# %% [markdown]
# ## Overall Findings of Heart Attack Risk Factors
#
# This analysis examined the relationship between various factors and the risk of heart attack. Here's a summary of the key findings:
#
# ### Demographics:
# - **Gender:** The percentage of men with a heart attack risk is slightly higher than the percentage of women with a heart attack risk. However, the overall risk of heart disease is similar for both men and women.
#
# - **Age:** The heart attack risk can occur at any age, even in young people, but it is more likely to occur in older people.
#
# ### Lifestyle Factors:
# - **Smoking and Alcohol consumption:**
# The heart attack risk percentage is slightly higher for non-smokers and non-alcoholics than for smokers and alcoholics, respectively. However, the difference is relatively small. It is important to note that these are just averages, and the individual risk of heart attack can vary depending on a number of factors, including age, gender, family history, and other medical conditions.
#
# - **Sleep, exercise, and physical activity:**
# People with good sleep and exercise levels and more physical activity days have a lower risk of heart attack.
#
# - **Diet:**
# Healthy group has the most people, the percentage of people with heart attack risk is also the highest (36.45%) compared to the Average (35.23%) and Unhealthy (35.77%) groups. Therefore, while the larger population size in the Healthy group contributes to the higher absolute number of heart attacks, it is not the only explanation, there might be other factors at play, such as: Age distribution , Specific dietary components and Other lifestyle factors.
#
# ### Medical factors:
# - **Cholesterol:** People with higher cholesterol levels have a higher risk of heart attack.
#
# - **Blood pressure:** People with high blood pressure have a higher risk of heart attack.
#
# - **Heart rate:** People with heart attack tend to have higher heart rates than people with no heart attack.
#
# - **Diabetes, family history, and previous heart problems:** These factors significantly increase the risk of heart attack.
#
# - **Triglycerides:** People with higher triglyceride levels have a higher risk of heart attack.
#
# ### Geographic factors:
# - **Countries:** The risk of heart attack varies across countries, with **Nigeria** having the highest risk among the studied countries.
#
# - **Continents:** **Asia** has the highest risk of heart attack, followed by Europe , South America , North America ,Africa and Australia.
#
# - **Hemisphere:** The northern hemisphere has a higher overall risk of heart attack compared to the southern hemisphere.
#
# ### Overall:
#
# - Managing medical conditions like high blood pressure, cholesterol, and diabetes is crucial for reducing risk.
#
# - Age, family history, and geographic location also play a role in heart attack risk.
#
#
# This analysis provides valuable insights into the complex interplay of various factors contributing to heart attack risk. By understanding these risk factors, individuals can take proactive steps to modify their lifestyle, manage medical conditions, and seek preventive care to reduce their risk and improve their cardiovascular health.

# %% [markdown]
# <div style="text-align:center;">
#     <img src="https://media.giphy.com/media/cd6Fp0qEGR3ag/giphy.gif" alt="Centered Image">
# </div>

# %% [markdown]
# # Exploring Heart Attack Risk Factors in the Heart_Dataset :
#
# This report summarizes my exploration of the Heart Data dataset, focusing on identifying potential risk factors for heart attack. I utilized various visualization techniques like histograms, boxplots, and density plots to analyze the relationships between heart attack risk and different variables.
#
# I used a variety of exploratory data analysis techniques to summarize the data and identify patterns. I used histograms to visualize the distribution of numerical variables and box plots to compare the distribution of numerical variables across different groups. I used crosstabs to identify relationships between categorical variables.
#
# ## I analyzed the Heart dataset to identify potential risk factors for heart attack. Here's a summary of what I did:
#
# ### 1. Data exploration:
#
# * Imported pandas, numpy, matplotlib, seaborn libraries.
# * Loaded the data from a Excel file and checked for missing values, duplicates and inconsistencies.
# * Performed basic cleaning and preprocessing to ensure data quality.
# * Calculated summary statistics to understand the distribution of each variable.
#
# ### 2. Visualizations:
#
# * Created histograms, boxplots, and density plots to visualize the distribution of key variables (e.g., heart rate, blood pressure, cholesterol levels, triglyceride levels) for different heart attack risk groups.
# * Used these visualizations to identify potential trends, differences, and outliers.
#
# ### 3. Findings :
#
# #### Heart disease risk factors:
#
# * **High cholesterol:** People with higher cholesterol levels have a higher risk of heart attack.
# * **Smoking and Alcohol consumption:** The heart attack risk percentage is slightly higher for non-smokers and non-alcoholics than for smokers and alcoholics, respectively. However, the difference is relatively small. It is important to note that these are just averages, and the individual risk of heart attack can vary depending on a number of factors, including age, gender, family history, and other medical conditions.
# * **Blood pressure:** Both systolic and diastolic blood pressure are higher in people with heart attack risk than in people without heart attack risk.
# * **Heart rate:** People with heart attack tend to have higher heart rates than people with no heart attack.
# * **Sleep, exercise, and physical activity:** People with a higher sum of sleep hours per day and exercise hours per week, and more physical activity days per week, have a lower risk of heart attack.
# * **Diabetes, family history, and previous heart problems:** Individuals with these risk factors have a significantly higher likelihood of having a heart attack.
# * **Triglyceride levels:** The higher the triglyceride levels, the higher the heart attack risk.
#
# ### 4. Hurdes and Difficulties:
#
# * I found the graphs interpreting and also quite challenging, especially density plots, histograms, and boxplots. It took me significantly longer than expected to understand what they were showing and draw meaningful conclusions.
#
# * For instance, distinguishing between normal and skewed distributions in density plots was tricky relying solely on visuals. I had to research and learn about concepts to feel confident in my interpretations.
#
# * Despite the initial difficulties, I spent significant time analyzing the graphs, comparing them to other visualizations, and striving to understand the underlying data distributions. I also consulted online resources and the textbook, which helped me grasp the concepts better.
#
# ### 5. Additional Analysis:
#
# While I've explored the relationships between some key factors and heart attack risk, I believe examining the following aspects would provide further valuable insights:
#
# * The relationship between stress levels and heart attack risk.
# * The relationship between income and heart attack risk.
# * The relationship between BMI(Body Mass Index) and heart attack risk.
#
# **Additionally:**
#
# * **Longitudinal Data:** If available, investigating data that tracks individuals over time can reveal how changes in stress, income, and BMI impact heart attack risk throughout their lives. This provides a more dynamic perspective and could inform risk prediction models.
#
# * **Social Determinants of Health:** Consider how broader social factors like education, race, and gender intersect with stress, income, and BMI to influence heart attack risk. Recognizing these interconnected layers is crucial for promoting health equity.
#
# By exploring these additional avenues, we can move beyond simple correlations and build a richer tapestry of understanding. This knowledge can inform more effective prevention strategies, targeted interventions, and policy changes that address the root causes of heart disease and create a healthier future for everyone.
#
# ### Conclusion:
#
# The initial exploration of the Heart dataset provided valuable insights into potential risk factors for heart attack. While challenges like data distributions and group comparisons arose, the appropriate research and visualizations helped overcome them. Further analysis, as outlined above, will delve deeper into the data, leading to a more comprehensive understanding of heart attack risk and potentially aiding in the development of better prevention strategies.
